# %%
import random
import glob
import os
import numpy as np
import cv2
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
import matplotlib
from matplotlib import font_manager
from PIL import Image

import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torchvision import models as models
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Inspection of the dataset

# %%
import pandas as pd

# %%
train_csv = pd.read_csv("lits_train.csv")
test_csv = pd.read_csv("lits_test.csv")

# %%
train_csv.tail()
# Out:
#                                       filepath  \
# 38518  ./lits-png/dataset_6/volume-130_509.png
# 38519  ./lits-png/dataset_6/volume-130_254.png
# 38520  ./lits-png/dataset_6/volume-130_510.png
# 38521  ./lits-png/dataset_6/volume-130_255.png
# 38522  ./lits-png/dataset_6/volume-130_511.png
#
#                                           liver_maskpath  \
# 38518  ./lits-png/dataset_6/segmentation-130_livermas...
# 38519  ./lits-png/dataset_6/segmentation-130_livermas...
# 38520  ./lits-png/dataset_6/segmentation-130_livermas...
# 38521  ./lits-png/dataset_6/segmentation-130_livermas...
# 38522  ./lits-png/dataset_6/segmentation-130_livermas...
#
#                                           tumor_maskpath  study_number  \
# 38518  ./lits-png/dataset_6/segmentation-130_lesionma...           130
# 38519  ./lits-png/dataset_6/segmentation-130_lesionma...           130
# 38520  ./lits-png/dataset_6/segmentation-130_lesionma...           130
# 38521  ./lits-png/dataset_6/segmentation-130_lesionma...           130
# 38522  ./lits-png/dataset_6/segmentation-130_lesionma...           130
#
#        instance_number  liver_mask_empty  tumor_mask_empty
# 38518              253              True              True
# 38519              254             False             False
# 38520              254              True              True
# 38521              255             False             False
# 38522              255              True              True

# %%
class LiTSDataset(Dataset):
    """LiTS dataset."""

    def __init__(self, csv_file, liver_or_lesion="liver_maskpath",transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.csv = pd.read_csv(csv_file)
        self.liver_or_lesion = liver_or_lesion
        self.transform = transform

    def __len__(self):
        return len(self.csv)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
        image = np.array(Image.open(self.csv.loc[idx]["filepath"]).convert("L"))
        mask = np.array(Image.open(self.csv.loc[idx][self.liver_or_lesion]).convert("L"), dtype=np.float32)

        image = cv2.cvtColor(clahe.apply(image), cv2.COLOR_GRAY2RGB)
        
        if self.transform is not None:
            augmentations = self.transform(image=image, mask=mask)
            image = augmentations["image"]
            mask = augmentations["mask"]

        return image, mask

# %%
train_liver_dataset = LiTSDataset(csv_file="lits_train.csv")
train_lesion_dataset = LiTSDataset(csv_file="lits_train.csv", liver_or_lesion="tumor_maskpath")
train_liver_loader = DataLoader(train_liver_dataset, batch_size=16, shuffle=True)
train_lesion_loader = DataLoader(train_lesion_dataset, batch_size=16, shuffle=True)

# %%
img = cv2.imread('./lits-png/dataset_6/volume-130_511.png', cv2.IMREAD_GRAYSCALE)
print(img.shape)
print(train_liver_dataset[38522][0].shape)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(train_liver_dataset[38522][0])
imgplot = plt.imshow(cl1,'gray', interpolation=None)
# Out:
# (256, 256)
# (256, 256, 3)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[48], line 5
#       3 print(train_liver_dataset[38522][0].shape)
#       4 clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
# ----> 5 cl1 = clahe.apply(train_liver_dataset[38522][0])
#       6 imgplot = plt.imshow(cl1,'gray', interpolation=None)
#
# error: OpenCV(4.9.0) /io/opencv/modules/imgproc/src/clahe.cpp:353: error: (-215:Assertion failed) _src.type() == CV_8UC1 || _src.type() == CV_16UC1 in function 'apply'

# %%
_, figure = plt.subplots(1, 3, figsize=(10, 30))

figure[0].imshow(train_liver_dataset[38522][0], 'gray', interpolation=None)
figure[1].imshow(train_liver_dataset[38522][0], 'gray', interpolation=None)
figure[1].imshow(train_liver_dataset[38522][1], interpolation=None, alpha=0.1)
figure[2].imshow(train_lesion_dataset[38522][0], 'gray', interpolation=None)
figure[2].imshow(train_lesion_dataset[38522][1], interpolation=None, alpha=0.1)
plt.show()

# %%
from torchmetrics.functional.classification import dice

def check_accuracy(loader, model, device="cuda"):
    num_correct = 0
    num_pixels = 0
    dice_score = 0
    model.eval()

    with torch.no_grad():
        for x, y in loader:
            x = x.float().permute(0, 3, 1, 2).to(device)
            y = y.to(device).unsqueeze(1).float()
            preds = torch.sigmoid(model(x)['out'])
            preds = (preds > 0.5).float()
            num_correct += (preds == y).sum()
            num_pixels += torch.numel(preds)
            dice_score += dice(preds, y.int())
        
    print(
        f"Got {num_correct}/{num_pixels} with acc {num_correct/num_pixels*100:.2f}"
    )
    print(f"Dice score: {dice_score/len(loader)}")
    model.train()

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 16
NUM_EPOCHS = 5
NUM_WORKERS = 2
IMAGE_HEIGHT = 160
IMAGE_WIDTH = 240
PIN_MEMORY = True
LOAD_MODEL = False
TRAIN_IMG_DIR = "data/train_images"
TRAIN_MASK_DIR = "data/train_masks"
VAL_IMG_DIR = "data/val_images"
VAL_MASK_DIR = "data/val_masks"

# %%
def train_fn(loader, model, optimizer, loss_fn, scaler):
    loop = tqdm(loader)

    for batch_idx, (data, targets) in enumerate(loop):
        # print(type(data))
        data = data.float().permute(0, 3, 1, 2).to(device=DEVICE)

        targets = targets.float().unsqueeze(1).to(device=DEVICE)
        # print(data.shape, targets.shape)

        # forward
        with torch.cuda.amp.autocast():
            predictions = model(data)
            
            predictions = predictions['out']
            predictions = torch.sigmoid(predictions)
            # predictions = (predictions > 0.5).float()
            loss = loss_fn(predictions, targets)

        # Backward
        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # update tqdm loop
        loop.set_postfix(loss=loss.item())

# %%
from torchvision.models.segmentation import fcn_resnet50, FCN_ResNet50_Weights

weights = FCN_ResNet50_Weights.DEFAULT
transforms = weights.transforms(resize_size=None)

model = fcn_resnet50(num_classes=1)

# %%
from monai.losses.dice import *  # NOQA

import torch

from monai.losses import FocalLoss


model.cuda()
loss_fn = FocalLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
scaler = torch.cuda.amp.GradScaler()

# %%
test_liver_dataset = LiTSDataset(csv_file="lits_test.csv")
test_lesion_dataset = LiTSDataset(csv_file="lits_test.csv", liver_or_lesion="tumor_maskpath")
test_liver_loader = DataLoader(test_liver_dataset, batch_size=16, shuffle=False)
test_lesion_loader = DataLoader(test_lesion_dataset, batch_size=16, shuffle=False)

# %%
import torchvision

def save_predictions_as_imgs(
    loader, model, folder="saved_images/", device="cuda"
):
    model.eval()
    for idx, (x, y) in enumerate(loader):
        x = x.float().to(device=device)
        with torch.no_grad():
            preds = torch.sigmoid(model(x)['out'])
            preds = (preds > 0.5).float()
        torchvision.utils.save_image(
            preds, f"{folder}pred_{idx}.png"
        )
        torchvision.utils.save_image(y.unsqueeze(1), f"{folder}{idx}.png")

    model.train()

# %%
for epoch in range(NUM_EPOCHS):
    train_fn(train_liver_loader, model, optimizer, loss_fn, scaler)
    # check accuracy
    check_accuracy(test_liver_loader, model, device=DEVICE)

    # save_predictions_as_imgs(test_liver_loader, model, folder="saved_images/", device=DEVICE)
# Out:
#   0%|          | 0/2408 [00:00<?, ?it/s]
# Got 198252015/199098368 with acc 99.57
# Dice score: 0.6032465696334839
#   0%|          | 0/2408 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 for epoch in range(NUM_EPOCHS):
# ----> 2     train_fn(train_liver_loader, model, optimizer, loss_fn, scaler)
#       3     # check accuracy
#       4     check_accuracy(test_liver_loader, model, device=DEVICE)
#
# Cell In[26], line 23, in train_fn(loader, model, optimizer, loss_fn, scaler)
#      21 optimizer.zero_grad()
#      22 scaler.scale(loss).backward()
# ---> 23 scaler.step(optimizer)
#      24 scaler.update()
#      26 # update tqdm loop
#
# File ~/miniconda3/envs/deeplearning/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:452, in GradScaler.step(self, optimizer, *args, **kwargs)
#     446     self.unscale_(optimizer)
#     448 assert (
#     449     len(optimizer_state["found_inf_per_device"]) > 0
#     450 ), "No inf checks were recorded for this optimizer."
# --> 452 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     454 optimizer_state["stage"] = OptState.STEPPED
#     456 return retval
#
# File ~/miniconda3/envs/deeplearning/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:349, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     341 def _maybe_opt_step(
#     342     self,
#     343     optimizer: torch.optim.Optimizer,
#    (...)
#     346     **kwargs: Any,
#     347 ) -> Optional[float]:
#     348     retval: Optional[float] = None
# --> 349     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     350         retval = optimizer.step(*args, **kwargs)
#     351     return retval
#
# File ~/miniconda3/envs/deeplearning/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:349, in <genexpr>(.0)
#     341 def _maybe_opt_step(
#     342     self,
#     343     optimizer: torch.optim.Optimizer,
#    (...)
#     346     **kwargs: Any,
#     347 ) -> Optional[float]:
#     348     retval: Optional[float] = None
# --> 349     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     350         retval = optimizer.step(*args, **kwargs)
#     351     return retval
#
# KeyboardInterrupt:

# %%
def save_checkpoint(state, filename="try_02.pth.tar"):
    print("=> Saving checkpoint")
    torch.save(state, filename)

# %%
checkpoint = {"state_dict": model.state_dict(),"optimizer":optimizer.state_dict()}
save_checkpoint(checkpoint)
# Out:
# => Saving checkpoint

# %%
def load_checkpoint(checkpoint, model):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint["state_dict"])

# %%
load_checkpoint(torch.load('try_01.tar'), model=model)
# Out:
# => Loading checkpoint
